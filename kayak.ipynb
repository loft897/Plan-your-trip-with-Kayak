# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import os
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "notebook"

import boto3
from sqlalchemy import create_engine, text

# %% [markdown]
# # Infos Villes

# %%
selected_cities = ["Mont Saint Michel", "St Malo", "Bayeux", "Le Havre", "Rouen", "Paris", "Amiens", "Lille", "Strasbourg", "Chateau du Haut Koenigsbourg", "Colmar", "Eguisheim", "Besancon", "Dijon", "Annecy", "Grenoble", "Lyon", "Aups", "Bormes les Mimosas", "Cassis", "Marseille", "Aix en Provence", "Avignon", "Uzes", "Nimes", "Aigues Mortes", "Saintes Maries de la mer", "Collioure", "Carcassonne", "Foix", "Toulouse", "Montauban", "Biarritz", "Bayonne", "La Rochelle"]

# %% [markdown]
# On récupère les coordonnées des villes depuis d'Openstreetmap

# %%
coord_cities_list = {}
cities_infos_list = []

for city in selected_cities:
    url = f'https://nominatim.openstreetmap.org/search?q={city}&format=json'
    data = requests.get(url).json()
    lon = float(data[0]['lon'])
    lat = float(data[0]['lat'])
    coord_cities_list[city.lower()] = {'lon': '%.2f' % lon, 'lat': '%.2f' % lat}
    
    cities_infos_list.append({
        'city': city,
        'longitude': '%.2f' % lon,
        'latitude': '%.2f' % lat,
    })

# On convertit la liste en DataFrame
cities_infos = pd.DataFrame(cities_infos_list)

# %%
cities_infos.sample(5)
# Out:
#                   city longitude latitude
# 18  Bormes les Mimosas      6.34    43.15
# 23                Uzes      4.42    44.01
# 27           Collioure      3.08    42.53
# 7                Lille      3.06    50.64
# 19              Cassis      5.54    43.21

# %%
# On sauvegarde le fichier des coordonées des villes

cities_infos.to_csv('files/cities_infos.csv', index=False)

# %% [markdown]
# # Données Météo

# %%
# Chargement de l'API key et définition de l'URL de l'API
api_key = os.environ.get('api_key')
cities_infos = pd.read_csv('files/cities_infos.csv')
url_weather = "https://api.openweathermap.org/data/3.0/onecall?lat={}&lon={}&exclude=current,minutely,hourly&units=metric&appid={}"


# fonction pour récupérer les données météo d'une ville spécifique
def fetch_weather_data(city, lat, lon):
    
    response = requests.get(url_weather.format(lat, lon, api_key))
    data = response.json()['daily']

    # Extraction des données de température, météo, couverture nuageuse et pluie
    temperatures = [day['temp']['day'] for day in data]
    weather = [day['weather'][0]['main'] for day in data]
    cloudiness = [day['clouds'] for day in data]
    predicted_rain = sum(day.get('pop', 0) * day.get('rain', 0) for day in data)

 

    # Retour des données pour la ville courante
    return {
        'cities': city,
        'latitude': lat,
        'longitude': lon,
        'main_weather_7days': pd.Series(weather).mode()[0],
        'rain_amount_7days': int(predicted_rain),
        'temp_7days': int(pd.Series(temperatures).mean()),
        'clouds_7days': int(pd.Series(cloudiness).mean())
    }

# Appel fonction fetch_weather_data à chaque ligne du dataframe cities_infos
weather_data = pd.DataFrame(
    fetch_weather_data(row['city'], row['latitude'], row['longitude']) 
    for _, row in cities_infos.iterrows()
)

# Calcul de la qualité météo en se basant sur les températures, la couverture nuageuse et la pluie
weather_data['quality'] = round((weather_data['temp_7days']*2) - (weather_data['clouds_7days']/4) - (weather_data['rain_amount_7days']*2), 2)

# Tri des données météo par qualité décroissante
weather_data = weather_data.sort_values(by=['quality'], ascending=False).reset_index(drop=True)

# Affichage des données météo
display(weather_data)
# Out:
#                           cities  latitude  longitude main_weather_7days  \
# 0             Bormes les Mimosas     43.15       6.34              Clear
# 1                           Aups     43.63       6.23             Clouds
# 2                         Cassis     43.21       5.54              Clear
# 3                      Marseille     43.30       5.37              Clear
# 4                          Nimes     43.84       4.36              Clear
# 5                Aix en Provence     43.53       5.45              Clear
# 6                      Collioure     42.53       3.08               Rain
# 7                        Avignon     43.95       4.81              Clear
# 8                  Aigues Mortes     43.57       4.19             Clouds
# 9                           Uzes     44.01       4.42              Clear
# 10                   Carcassonne     43.21       2.35               Rain
# 11                      Toulouse     43.60       1.44               Rain
# 12                     Montauban     44.02       1.35               Rain
# 13      Saintes Maries de la mer     43.45       4.43              Clear
# 14                          Foix     42.96       1.61               Rain
# 15                         Dijon     47.32       5.04               Rain
# 16                   La Rochelle     46.16      -1.15               Rain
# 17                     Eguisheim     48.04       7.31               Rain
# 18                      Besancon     47.24       6.02               Rain
# 19                      Grenoble     45.19       5.74               Rain
# 20                        Colmar     48.08       7.36               Rain
# 21                          Lyon     45.76       4.83               Rain
# 22                       Bayonne     43.49      -1.47               Rain
# 23                      Biarritz     43.47      -1.55               Rain
# 24                         Paris     48.85       2.35             Clouds
# 25  Chateau du Haut Koenigsbourg     48.25       7.34               Rain
# 26                        Amiens     49.89       2.30               Rain
# 27                       St Malo     48.65      -2.03               Rain
# 28                        Bayeux     49.28      -0.70               Rain
# 29             Mont Saint Michel     48.64      -1.51               Rain
# 30                         Lille     50.64       3.06               Rain
# 31                    Strasbourg     48.58       7.75               Rain
# 32                         Rouen     49.44       1.09               Rain
# 33                        Annecy     45.90       6.13               Rain
# 34                      Le Havre     49.49       0.11               Rain
#
#     rain_amount_7days  temp_7days  clouds_7days  quality
# 0                   0          28            19    51.25
# 1                   1          29            23    50.25
# 2                   2          27            19    45.25
# 3                   3          27            20    43.00
# 4                   5          30            38    40.50
# 5                   6          29            26    39.50
# 6                   5          27            29    36.75
# 7                   8          30            37    34.75
# 8                   6          27            36    33.00
# 9                   9          30            36    33.00
# 10                  6          28            47    32.25
# 11                  5          26            63    26.25
# 12                  5          25            57    25.75
# 13                 11          26            36    21.00
# 14                  7          24            64    18.00
# 15                  8          24            57    17.75
# 16                  6          20            68    11.00
# 17                 16          23            73    -4.25
# 18                 17          22            61    -5.25
# 19                 24          26            44    -7.00
# 20                 19          23            73   -10.25
# 21                 25          25            54   -13.50
# 22                 23          22            55   -15.75
# 23                 22          21            55   -15.75
# 24                 19          21            82   -16.50
# 25                 19          19            79   -19.75
# 26                 24          20            82   -28.50
# 27                 25          19            68   -29.00
# 28                 29          20            81   -38.25
# 29                 30          20            75   -38.75
# 30                 31          20            79   -41.75
# 31                 34          23            83   -42.75
# 32                 36          20            78   -51.50
# 33                 44          24            47   -51.75
# 34                 43          19            75   -66.75

# %%
# On sauvegarde les données meteorologiques des villes

weather_data.to_csv('files/cities_weather_data.csv', index=False)

# %% [markdown]
# # Infos Hotels

# %%
weather_data = pd.read_csv('files/cities_weather_data.csv')

# Initialiser l'agent utilisateur pour les requêtes
agent = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36'}

# Construire les URL de recherche pour chaque ville du dataset météo
search_urls = ['https://www.booking.com/searchresults.fr.html?ss='+city+'&nflt=review_score%3D60' for city in weather_data['cities']]

# Récupérer les URL des hôtels (25 premiers sur la page de recherche de Booking) pour chaque URL de recherche
hotels_urls = []
for url in search_urls:
    page = requests.get(url, headers=agent)
    soup = BeautifulSoup(page.content, "html.parser")
    hotels_urls += [a['href'].split('?')[0] for a in soup.find_all('a',{"class": "e13098a59f"}, href=True)]

# Classe pour scraper les informations des hôtels
class BookingHotelInfo:
    def __init__(self):
        self.hotel_list = []
        self.hotel_data = {"name": "Empty", "address": "Empty", "description": "Empty",
                           "score": "Empty", "url": "Empty", "bonus": "Empty", "latlon": "Empty"}

    def get_hotel_data(self, url):
        session_object = requests.Session()
        page = session_object.get(url, headers=agent)
        soup = BeautifulSoup(page.content, "lxml")

        # Extraire les informations de l'hôtel
        for attribute, selector in zip(["name", "address", "description", "score", "bonus", "latlon"],
                                       ["h2.pp-header__title", "span.hp_address_subtitle", "div.hp_desc_main_content",
                                        "a.hp_review_score", "div.hp_desc_important_facilities", "a.show_map"]):
            try:
                self.hotel_data[attribute] = soup.select_one(selector).text.strip() if attribute != "latlon" else soup.select_one(selector).get('data-atlas-latlng')
            except:
                pass

        self.hotel_data["url"] = url
        self.hotel_list.append(self.hotel_data)

# Récupérer les données des hôtels pour chaque URL d'hôtel
hotels_list = []
for url in hotels_urls:
    hotel = BookingHotelInfo()
    hotel.get_hotel_data(url)
    hotels_list.append(hotel.hotel_list[:])

# Créer un nouveau dataframe avec les informations des hôtels
booking_data = weather_data.copy()
booking_data = booking_data.loc[weather_data.index.repeat(25)]
booking_data = booking_data.drop(['latitude','longitude','main_weather_7days','rain_amount_7days','temp_7days','clouds_7days','quality'],axis=1)
booking_data['raw_data'] = hotels_list

booking_data['raw_data'] = booking_data['raw_data'].apply(pd.Series)
hotel_data = booking_data.raw_data.apply(pd.Series)
booking_data = pd.concat([booking_data, hotel_data],axis=1).drop('raw_data', axis=1).reset_index()

# Nettoyage des données textuelles
for col, pattern, replacement in zip(["description", "score", "bonus"],
                                     ["\n", "\xa0", "\n"],
                                     ["", "", " "]):
    booking_data[col] = booking_data[col].str.replace(pattern, replacement)

# Extraire la latitude et la longitude à partir des coordonnées et supprimer la colonne 'latlon'
booking_data[['latitude', 'longitude']] = booking_data['latlon'].str.split(',', expand=True)
booking_data = booking_data.drop('latlon',axis=1)

# Convertir les types de données
booking_data[['latitude','longitude']] = booking_data[['latitude','longitude']].astype(float)

# On va utiliser une expression régulière pour extraire le score
booking_data['score'] = booking_data['score'].str.extract('(\d+[\.,]?\d*)', expand=False).str.replace(',', '.').astype(float)

# %%
# On sauvegarde les données sur les differents hotels

booking_data.to_csv('files/booking_data.csv', index=False)

# %%
booking_data.sample(5)
# Out:
#      index                    cities  \
# 329     13  Saintes Maries de la mer
# 71       2                    Cassis
# 263     10               Carcassonne
# 776     31                Strasbourg
# 804     32                     Rouen
#
#                                              name  \
# 329                             Thalacap Camargue
# 71           AQUARIUS IN CASSIS, Chambres d'Hôtes
# 263                       Hôtel Montmorency & Spa
# 776  très joli T2 tout neuf en ville avec parking
# 804               Hôtel Céline - Hôtel de la Gare
#
#                                                address  \
# 329  Avenue du Dr Cambon, 13460 Les Saintes-Maries-...
# 71         22 Impasse des Brayes, 13260 Cassis, France
# 263  2 Rue Camille Saint Saens, 11000 Carcassonne, ...
# 776  appartement numéro 4 23 Rue Vauban, 67000 Stra...
# 804           26 rue De Campulley, 76000 Rouen, France
#
#                                            description  score  \
# 329  Le Thalacap Camargue est situé en face de la p...    7.7
# 71   Situé à Cassis, à 1,2 km de Bestouan, l'AQUARI...    9.4
# 263  Vous pouvez bénéficier d'une réduction Genius ...    8.3
# 776  Le très joli T2 tout neuf en ville avec parkin...    6.0
# 804  L'Hôtel Céline - Hôtel de la Gare se trouve da...    8.0
#
#                                                    url  bonus   latitude  \
# 329  https://www.booking.com/hotel/fr/thalacap-cama...  Empty  43.453491
# 71   https://www.booking.com/hotel/fr/aquarius-in-c...  Empty  43.222355
# 263  https://www.booking.com/hotel/fr/montmorency.f...  Empty  43.207066
# 776  https://www.booking.com/hotel/fr/tres-joli-t2-...  Empty  48.580934
# 804  https://www.booking.com/hotel/fr/hotel-celine....  Empty  49.449034
#
#      longitude
# 329   4.435451
# 71    5.534539
# 263   2.367087
# 776   7.773012
# 804   1.090211

# %% [markdown]
# # Stockage avec AWS S3

# %%
# On cree un bucket s3 Amazon

ACCESS_KEY_ID = os.environ.get('aws_access_key_id')
SECRET_ACCESS_KEY = os.environ.get('aws_secret_access_key')

bucketname = 'galus-fotso-files'

# %%
session = boto3.Session(
    aws_access_key_id= ACCESS_KEY_ID,
    aws_secret_access_key= SECRET_ACCESS_KEY
)

s3 = session.client("s3")

bucket = s3.create_bucket(Bucket=bucketname, ACL='public-read-write', CreateBucketConfiguration={'LocationConstraint': 'eu-west-3'})

# %%
# Chargement des fichiers

s3.Bucket(bucketname).upload_file('files/booking_data.csv','booking_data.csv')
s3.Bucket(bucketname).upload_file('files/cities_weather_data.csv','cities_weather_data.csv')

# %%
# Telechargement d'un dataset pour tester le upload

booking_data = pd.read_csv(f"https://{bucketname}.s3.eu-west-3.amazonaws.com/booking_data.csv")
booking_data.head()
# Out:
#    index              cities  \
# 0      0  Bormes les Mimosas
# 1      0  Bormes les Mimosas
# 2      0  Bormes les Mimosas
# 3      0  Bormes les Mimosas
# 4      0  Bormes les Mimosas
#
#                                                 name  \
# 0                                      Hôtel Paradis
# 1                                     Hotel La Voile
# 2                          Hotel Restaurant Bellevue
# 3  Bormes les Mimosas, à 5 min des plages - comme...
# 4  Studio avec Clim, Parking et Balcon - 3 personnes
#
#                                              address  \
# 0  62 Impasse du Castellan, 83230 Bormes-les-Mimo...
# 1  165 Avenue Des Girelles - La Favière, 83230 Bo...
# 2  14 place Gambetta, 83230 Bormes-les-Mimosas, F...
# 3  Côte d'Azur IV appartement 69 169 Avenue de la...
# 4  immeuble 9 - Bâtiment COTE D'AZUR 280 Avenue d...
#
#                                          description  score  \
# 0  L'hôtel Paradis occupe un bâtiment datant de 1...    8.2
# 1  L'Hotel La Voile est idéalement situé à seulem...    7.6
# 2  Situé dans le centre-ville de Bormes-les-Mimos...    7.6
# 3  Situé à Bormes-les-Mimosas, à 700 mètres de la...    9.0
# 4  Le Studio avec Clim, Parking et Balcon - 3 per...    7.0
#
#                                                  url  bonus   latitude  \
# 0   https://www.booking.com/hotel/fr/paradis.fr.html  Empty  43.144686
# 1  https://www.booking.com/hotel/fr/hotel-la-voil...  Empty  43.125490
# 2  https://www.booking.com/hotel/fr/restaurant-be...  Empty  43.151878
# 3  https://www.booking.com/hotel/fr/bormes-les-mi...  Empty  43.123145
# 4  https://www.booking.com/hotel/fr/studio-avec-c...  Empty  43.123150
#
#    longitude
# 0   6.335125
# 1   6.357300
# 2   6.343136
# 3   6.352572
# 4   6.353336

# %% [markdown]
# Sauvegarde du fichier dans une database RDS

# %%
login = open("login.txt", "r").readlines()

# %%
# Configuration de RDS

filename = "booking_data.csv"

s3.download_file(bucketname, filename, filename)

data = pd.read_csv(filename)

# Connexion à la base de données MySQL

# engine = create_engine(f"mysql+pymysql://{DBUSER}:{DBPASS}@{DBHOST}:{PORT}/{DBNAME}")
engine = create_engine(f"mysql+pymysql://{login[0].strip()}:{login[1].strip()}@{login[2].strip()}:{login[3].strip()}/{login[4].strip()}")

# Stocker les données dans la base de données
data.to_sql('booking_data', con=engine, index=False, if_exists='replace')

os.remove(filename)

# %%
engine
# Out:
# Engine(mysql+pymysql://admin:***@db-jed-project.caguutf4lyyc.eu-west-3.rds.amazonaws.com:3306/dbproject)

# %%
weather_data = pd.read_csv('files/cities_weather_data.csv')

# %%
# stocker les données météo et de réservation sous forme de tables SQL

weather_data.to_sql('weather', con=engine, if_exists='replace', index=False)
booking_data.to_sql('booking', con=engine, if_exists='replace', index=False)
# Out:
# 875

# %%
# Obtenir des données météorologiques à partir d'une table SQL

weather_query = text("SELECT * FROM weather WHERE quality > 10 ORDER BY quality DESC LIMIT 5")
weather_selection = pd.read_sql(weather_query, engine)
weather_selection.head()
# Out:
#                cities  latitude  longitude main_weather_7days  \
# 0  Bormes les Mimosas     43.15       6.34              Clear
# 1                Aups     43.63       6.23             Clouds
# 2              Cassis     43.21       5.54              Clear
# 3           Marseille     43.30       5.37              Clear
# 4               Nimes     43.84       4.36              Clear
#
#    rain_amount_7days  temp_7days  clouds_7days  quality
# 0                  0          28            19    51.25
# 1                  1          29            23    50.25
# 2                  2          27            19    45.25
# 3                  3          27            20    43.00
# 4                  5          30            38    40.50

# %%
# choisir les hôtels dont nous avons besoin en fonction de la météo

hotel_query = text("SELECT * FROM booking WHERE cities in ('Bormes les Mimosas','Aups','Cassis','Marseille','Nimes')")
hotel_selection = pd.read_sql(hotel_query, engine)
hotel_selection.head()
# Out:
#    index              cities  \
# 0      0  Bormes les Mimosas
# 1      0  Bormes les Mimosas
# 2      0  Bormes les Mimosas
# 3      0  Bormes les Mimosas
# 4      0  Bormes les Mimosas
#
#                                                 name  \
# 0                                      Hôtel Paradis
# 1                                     Hotel La Voile
# 2                          Hotel Restaurant Bellevue
# 3  Bormes les Mimosas, à 5 min des plages - comme...
# 4  Studio avec Clim, Parking et Balcon - 3 personnes
#
#                                              address  \
# 0  62 Impasse du Castellan, 83230 Bormes-les-Mimo...
# 1  165 Avenue Des Girelles - La Favière, 83230 Bo...
# 2  14 place Gambetta, 83230 Bormes-les-Mimosas, F...
# 3  Côte d'Azur IV appartement 69 169 Avenue de la...
# 4  immeuble 9 - Bâtiment COTE D'AZUR 280 Avenue d...
#
#                                          description  score  \
# 0  L'hôtel Paradis occupe un bâtiment datant de 1...    8.2
# 1  L'Hotel La Voile est idéalement situé à seulem...    7.6
# 2  Situé dans le centre-ville de Bormes-les-Mimos...    7.6
# 3  Situé à Bormes-les-Mimosas, à 700 mètres de la...    9.0
# 4  Le Studio avec Clim, Parking et Balcon - 3 per...    7.0
#
#                                                  url  bonus   latitude  \
# 0   https://www.booking.com/hotel/fr/paradis.fr.html  Empty  43.144686
# 1  https://www.booking.com/hotel/fr/hotel-la-voil...  Empty  43.125490
# 2  https://www.booking.com/hotel/fr/restaurant-be...  Empty  43.151878
# 3  https://www.booking.com/hotel/fr/bormes-les-mi...  Empty  43.123145
# 4  https://www.booking.com/hotel/fr/studio-avec-c...  Empty  43.123150
#
#    longitude
# 0   6.335125
# 1   6.357300
# 2   6.343136
# 3   6.352572
# 4   6.353336

# %% [markdown]
# # Représentation Graphique

# %%
fig = px.scatter_mapbox(hotel_selection, lat="latitude", lon="longitude", hover_name = 'name', zoom = 8,
                        hover_data={
        'latitude': False,
        'longitude': False,
        'score': True,
        'cities': True,
        'bonus': True,
        'description': False,
        'address' : False,
        'url' : False,
        'bonus' : False
        }, 
                        color = 'score', color_continuous_scale = px.colors.sequential.Jet, size='score',
                        mapbox_style="carto-positron", width = 1200, height = 800,
                        title='Hôtels les mieux notés dans les villes avec le meilleur temps au cours des 7 prochains jours')
fig.show()
# Out:
# <div>                            <div id="5902b472-1de8-4310-bbc0-c640b15109b4" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5902b472-1de8-4310-bbc0-c640b15109b4")) {                    Plotly.newPlot(                        "5902b472-1de8-4310-bbc0-c640b15109b4",                        [{"customdata":[[43.144686,6.335125,8.2,"Bormes les Mimosas","Empty","L'h\u00f4tel Paradis\u00a0occupe un b\u00e2timent datant\u00a0de 1920 et b\u00e9n\u00e9ficie d'un jardin luxuriant. Il offre une vue panoramique sur la mer et le vieux village de Bormes.Plusieurs chambres poss\u00e8dent un balcon donnant sur la mer, d'autres surplombent le village. Les chambres sont aussi \u00e9quip\u00e9es d'une connexion Wi-Fi gratuite et d'une t\u00e9l\u00e9vision.De plus, vous d\u00e9gusterez un petit-d\u00e9jeuner continental quotidien.\u00a0En fonction du\u00a0nombre de personnes, il peut \u00eatre propos\u00e9 sous forme de buffet. Le parking est accessible pour les v\u00e9los, les motos et les voitures.Bormes les Mimosas est situ\u00e9 entre Saint Tropez et Hy\u00e8res et offre des vues superbes sur l'\u00eele de Port Cros et Porquerolles.Les couples appr\u00e9cient particuli\u00e8rement l'emplacement de cet \u00e9tablissement. Ils lui donnent la note de 9,0 pour un s\u00e9jour \u00e0 deux.L'\u00e9tablissement H\u00f4tel Paradis accueille des clients Booking.com depuis le 4\u00a0juin\u00a02008.En voir plus","62 Impasse du Castellan, 83230 Bormes-les-Mimosas, France","https:\u002f\u002fwww.booking.com\u002fhotel\u002ffr\u002fparadis.fr.html"],[43.12549,6.3573,7.6,"Bormes les Mimosas","Empty","L'Hotel La Voile est id\u00e9alement situ\u00e9 \u00e0 seulement 400\u00a0m\u00e8tres des plages et du port de Bormes, dans un environnement calme et paisible \u00e0 proximit\u00e9 du village de La Favi\u00e8re. Il poss\u00e8de une piscine ext\u00e9rieure chauff\u00e9e et un bar-salon.Plusieurs chambres de l'h\u00f4tel offrent une vue sur la mer ou le jardin. Vous aurez le choix entre des chambres simples ou doubles, certaines pouvant accueillir jusqu'\u00e0 4\u00a0personnes.Chaque matin, un petit-d\u00e9jeuner buffet est servi dans le coin repas moyennant un suppl\u00e9ment. L'h\u00f4tel peut \u00e9galement vous recommander des restaurants dans les environs.Vous s\u00e9journerez \u00e0 proximit\u00e9 du charmant village m\u00e9di\u00e9val de Bormes-Les-Mimosas et \u00e0 moins de 100\u00a0m\u00e8tres des boutiques et des restaurants locaux. Dans les environs, vous aurez l'occasion de pratiquer de nombreux sports nautiques et activit\u00e9s de plein air. Un parking priv\u00e9 est disponible sur demande et moyennant un suppl\u00e9ment.En voir plus","165 Avenue Des Girelles - La Favi\u00e8re, 83230 Bormes-les-Mimosas, France","https:\u002f\u002fwww.booking.com\u002fhotel\u002ffr\u002fhotel-la-voile-fr.fr.html"],[43.15187759,6.34313598,7.6,"Bormes les Mimosas","Empty","Situ\u00e9 dans le centre-ville de Bormes-les-Mimosas, l'Hotel Restaurant Bellevue poss\u00e8de un restaurant servant des produits frais et locaux, un bar et une terrasse se trouvant en face de l'\u00e9tablissement. Des chambres pour personnes \u00e0 mobilit\u00e9 r\u00e9duite sont disponibles.Toutes les chambres non-fumeurs sont climatis\u00e9es et \u00e9quip\u00e9es d'une t\u00e9l\u00e9vision \u00e0 \u00e9cran plat, d'un coffre-fort et d'une connexion Wi-Fi gratuite. Les salles de bains privatives sont pourvues d'une douche, de toilettes et d'un s\u00e8che-cheveux.Un petit-d\u00e9jeuner buffet comprenant des p\u00e2tisseries traditionnelles, des fruits, des \u0153ufs et des jus de fruits est servi chaque matin moyennant un suppl\u00e9ment. Vous pourrez \u00e9galement profiter du bar-restaurant de l'\u00e9tablissement.L'Hotel Restaurant Bellevue se trouve \u00e0  ...

# %%
fig = px.scatter_mapbox(weather_selection, lat="latitude", lon="longitude", hover_name = 'cities', zoom = 4.5,
                        hover_data={
        'latitude': False,
        'longitude': False,
        'quality': True,
        'temp_7days': True,
        'rain_amount_7days': True,
        'main_weather_7days': True
        }, 
                        color = 'temp_7days', color_continuous_scale = px.colors.sequential.Rainbow, size='quality',
                        mapbox_style="carto-positron",width = 1200, height = 800,
                        title='Villes avec le meilleur temps en France au cours des 7 prochains jours')
fig.show()
# Out:
# <div>                            <div id="066fde57-5879-4084-834a-923fb22f1771" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("066fde57-5879-4084-834a-923fb22f1771")) {                    Plotly.newPlot(                        "066fde57-5879-4084-834a-923fb22f1771",                        [{"customdata":[[43.15,6.34,51.25,28,0,"Clear"],[43.63,6.23,50.25,29,1,"Clouds"],[43.21,5.54,45.25,27,2,"Clear"],[43.3,5.37,43.0,27,3,"Clear"],[43.84,4.36,40.5,30,5,"Clear"]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003equality=%{customdata[2]}\u003cbr\u003etemp_7days=%{marker.color}\u003cbr\u003erain_amount_7days=%{customdata[4]}\u003cbr\u003emain_weather_7days=%{customdata[5]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Bormes les Mimosas","Aups","Cassis","Marseille","Nimes"],"lat":[43.15,43.63,43.21,43.3,43.84],"legendgroup":"","lon":[6.34,6.23,5.54,5.37,4.36],"marker":{"color":[28,29,27,27,30],"coloraxis":"coloraxis","size":[51.25,50.25,45.25,43.0,40.5],"sizemode":"area","sizeref":0.128125},"mode":"markers","name":"","showlegend":false,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[ ...

# %% [markdown]
# On peut aller plus loin en proposant aux utilsateurs, les avis sur les hotels, les itineraires suggérés, alerte des prix quand ca chute, les activités attractives dans chaque ville.
